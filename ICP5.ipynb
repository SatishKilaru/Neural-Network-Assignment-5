# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.constraints import MaxNorm
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical  # Replace np_utils with to_categorical

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# load CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# one hot encode outputs using to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

# Create the model
model = Sequential()

# Convolutional input layer
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))

# Second convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the layers
model.add(Flatten())

# Fully connected layer
model.add(Dense(512, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(num_classes, activation='softmax'))

# Compile model
epochs = 100
lrate = 0.01
decay = lrate / epochs

# The 'lr' argument in the SGD optimizer has been updated to 'learning_rate' in the newer versions of TensorFlow/Keras
sgd = SGD(learning_rate=lrate, momentum=0.9, decay=decay, nesterov=False)

# Compile the model using categorical crossentropy loss and accuracy as the metric
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Display model summary
print(model.summary())

# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32, verbose=2)

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))

# Visualizing loss and accuracy
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       4,194,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,210,090 (16.06 MB)
#  Trainable params: 4,210,090 (16.06 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 1563/1563 - 17s - 11ms/step - accuracy: 0.3734 - loss: 1.7191 - val_accuracy: 0.5144 - val_loss: 1.3677
# Epoch 2/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.5113 - loss: 1.3621 - val_accuracy: 0.5734 - val_loss: 1.2053
# Epoch 3/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.5706 - loss: 1.2041 - val_accuracy: 0.6115 - val_loss: 1.1026
# Epoch 4/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.6180 - loss: 1.0791 - val_accuracy: 0.6378 - val_loss: 1.0369
# Epoch 5/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.6509 - loss: 0.9871 - val_accuracy: 0.6410 - val_loss: 1.0293
# Epoch 6/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.6824 - loss: 0.8977 - val_accuracy: 0.6490 - val_loss: 0.9967
# Epoch 7/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.7132 - loss: 0.8077 - val_accuracy: 0.6558 - val_loss: 1.0014
# Epoch 8/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.7419 - loss: 0.7282 - val_accuracy: 0.6637 - val_loss: 1.0053
# Epoch 9/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.7652 - loss: 0.6705 - val_accuracy: 0.6599 - val_loss: 1.0160
# Epoch 10/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.7901 - loss: 0.6023 - val_accuracy: 0.6732 - val_loss: 0.9920
# Epoch 11/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.8054 - loss: 0.5539 - val_accuracy: 0.6655 - val_loss: 1.0521
# Epoch 12/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.8255 - loss: 0.4959 - val_accuracy: 0.6754 - val_loss: 1.0913
# Epoch 13/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.8363 - loss: 0.4702 - val_accuracy: 0.6575 - val_loss: 1.1125
# Epoch 14/100
# 1563/1563 - 9s - 6ms/step - accuracy: 0.8512 - loss: 0.4271 - val_accuracy: 0.6792 - val_loss: 1.1632
# Epoch 15/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.8618 - loss: 0.4000 - val_accuracy: 0.6843 - val_loss: 1.0964
# Epoch 16/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.8715 - loss: 0.3736 - val_accuracy: 0.6814 - val_loss: 1.1721
# Epoch 17/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.8774 - loss: 0.3556 - val_accuracy: 0.6850 - val_loss: 1.1879
# Epoch 18/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.8831 - loss: 0.3388 - val_accuracy: 0.6841 - val_loss: 1.2415
# Epoch 19/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.8856 - loss: 0.3373 - val_accuracy: 0.6786 - val_loss: 1.3036
# Epoch 20/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.8925 - loss: 0.3150 - val_accuracy: 0.6846 - val_loss: 1.2528
# Epoch 21/100
# 1563/1563 - 5s - 4ms/step - accuracy: 0.8967 - loss: 0.3065 - val_accuracy: 0.6813 - val_loss: 1.2278
# Epoch 22/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9004 - loss: 0.2956 - val_accuracy: 0.6860 - val_loss: 1.2611
# Epoch 23/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.8989 - loss: 0.2989 - val_accuracy: 0.6888 - val_loss: 1.2145
# Epoch 24/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9016 - loss: 0.2907 - val_accuracy: 0.6804 - val_loss: 1.2295
# Epoch 25/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9042 - loss: 0.2869 - val_accuracy: 0.6810 - val_loss: 1.3082
# Epoch 26/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9064 - loss: 0.2753 - val_accuracy: 0.6800 - val_loss: 1.3415
# Epoch 27/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9095 - loss: 0.2708 - val_accuracy: 0.6747 - val_loss: 1.2321
# Epoch 28/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9099 - loss: 0.2713 - val_accuracy: 0.6747 - val_loss: 1.3038
# Epoch 29/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9111 - loss: 0.2666 - val_accuracy: 0.6569 - val_loss: 1.4565
# Epoch 30/100
# 1563/1563 - 9s - 6ms/step - accuracy: 0.9142 - loss: 0.2572 - val_accuracy: 0.6881 - val_loss: 1.2606
# Epoch 31/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9126 - loss: 0.2586 - val_accuracy: 0.6842 - val_loss: 1.4023
# Epoch 32/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9152 - loss: 0.2535 - val_accuracy: 0.6725 - val_loss: 1.4776
# Epoch 33/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9163 - loss: 0.2509 - val_accuracy: 0.6790 - val_loss: 1.3015
# Epoch 34/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9169 - loss: 0.2497 - val_accuracy: 0.6774 - val_loss: 1.3996
# Epoch 35/100
# 1563/1563 - 5s - 4ms/step - accuracy: 0.9192 - loss: 0.2417 - val_accuracy: 0.6885 - val_loss: 1.3050
# Epoch 36/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9200 - loss: 0.2354 - val_accuracy: 0.6844 - val_loss: 1.3809
# Epoch 37/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9196 - loss: 0.2365 - val_accuracy: 0.6809 - val_loss: 1.3544
# Epoch 38/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9185 - loss: 0.2429 - val_accuracy: 0.6696 - val_loss: 1.4289
# Epoch 39/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9207 - loss: 0.2327 - val_accuracy: 0.6816 - val_loss: 1.3699
# Epoch 40/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9236 - loss: 0.2271 - val_accuracy: 0.6833 - val_loss: 1.3398
# Epoch 41/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9224 - loss: 0.2327 - val_accuracy: 0.6851 - val_loss: 1.2859
# Epoch 42/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9243 - loss: 0.2281 - val_accuracy: 0.6894 - val_loss: 1.2828
# Epoch 43/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9230 - loss: 0.2310 - val_accuracy: 0.6804 - val_loss: 1.3054
# Epoch 44/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9240 - loss: 0.2303 - val_accuracy: 0.6778 - val_loss: 1.3438
# Epoch 45/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9280 - loss: 0.2202 - val_accuracy: 0.6833 - val_loss: 1.3792
# Epoch 46/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9269 - loss: 0.2218 - val_accuracy: 0.6708 - val_loss: 1.4782
# Epoch 47/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9293 - loss: 0.2170 - val_accuracy: 0.6865 - val_loss: 1.3712
# Epoch 48/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9275 - loss: 0.2210 - val_accuracy: 0.6831 - val_loss: 1.4542
# Epoch 49/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.9295 - loss: 0.2140 - val_accuracy: 0.6850 - val_loss: 1.3865
# Epoch 50/100
# 1563/1563 - 9s - 6ms/step - accuracy: 0.9275 - loss: 0.2187 - val_accuracy: 0.6763 - val_loss: 1.3786
# Epoch 51/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9269 - loss: 0.2191 - val_accuracy: 0.6831 - val_loss: 1.2603
# Epoch 52/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9279 - loss: 0.2154 - val_accuracy: 0.6725 - val_loss: 1.4773
# Epoch 53/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9277 - loss: 0.2153 - val_accuracy: 0.6736 - val_loss: 1.3889
# Epoch 54/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9304 - loss: 0.2124 - val_accuracy: 0.6742 - val_loss: 1.3409
# Epoch 55/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9296 - loss: 0.2106 - val_accuracy: 0.6755 - val_loss: 1.4137
# Epoch 56/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9337 - loss: 0.2038 - val_accuracy: 0.6763 - val_loss: 1.4914
# Epoch 57/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9319 - loss: 0.2061 - val_accuracy: 0.6652 - val_loss: 1.4649
# Epoch 58/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9320 - loss: 0.2079 - val_accuracy: 0.6811 - val_loss: 1.4131
# Epoch 59/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9313 - loss: 0.2095 - val_accuracy: 0.6848 - val_loss: 1.3591
# Epoch 60/100
# 1563/1563 - 5s - 4ms/step - accuracy: 0.9344 - loss: 0.2020 - val_accuracy: 0.6867 - val_loss: 1.4432
# Epoch 61/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9350 - loss: 0.2002 - val_accuracy: 0.6813 - val_loss: 1.4681
# Epoch 62/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9371 - loss: 0.1897 - val_accuracy: 0.6768 - val_loss: 1.3936
# Epoch 63/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9377 - loss: 0.1934 - val_accuracy: 0.6790 - val_loss: 1.4473
# Epoch 64/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9378 - loss: 0.1894 - val_accuracy: 0.6715 - val_loss: 1.4320
# Epoch 65/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9349 - loss: 0.2015 - val_accuracy: 0.6829 - val_loss: 1.4046
# Epoch 66/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9346 - loss: 0.2012 - val_accuracy: 0.6814 - val_loss: 1.3801
# Epoch 67/100
# 1563/1563 - 5s - 4ms/step - accuracy: 0.9386 - loss: 0.1887 - val_accuracy: 0.6850 - val_loss: 1.3776
# Epoch 68/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9372 - loss: 0.1896 - val_accuracy: 0.6741 - val_loss: 1.3617
# Epoch 69/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9359 - loss: 0.1945 - val_accuracy: 0.6760 - val_loss: 1.3590
# Epoch 70/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9349 - loss: 0.2024 - val_accuracy: 0.6807 - val_loss: 1.3898
# Epoch 71/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9389 - loss: 0.1870 - val_accuracy: 0.6774 - val_loss: 1.5007
# Epoch 72/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9351 - loss: 0.1975 - val_accuracy: 0.6800 - val_loss: 1.3704
# Epoch 73/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9365 - loss: 0.1922 - val_accuracy: 0.6816 - val_loss: 1.3899
# Epoch 74/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.9377 - loss: 0.1876 - val_accuracy: 0.6786 - val_loss: 1.4559
# Epoch 75/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9381 - loss: 0.1889 - val_accuracy: 0.6901 - val_loss: 1.3611
# Epoch 76/100
# 1563/1563 - 5s - 4ms/step - accuracy: 0.9366 - loss: 0.1942 - val_accuracy: 0.6897 - val_loss: 1.3713
# Epoch 77/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9388 - loss: 0.1854 - val_accuracy: 0.6815 - val_loss: 1.4322
# Epoch 78/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9357 - loss: 0.1954 - val_accuracy: 0.6828 - val_loss: 1.4331
# Epoch 79/100
# 1563/1563 - 10s - 6ms/step - accuracy: 0.9354 - loss: 0.1951 - val_accuracy: 0.6712 - val_loss: 1.4842
# Epoch 80/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9389 - loss: 0.1903 - val_accuracy: 0.6827 - val_loss: 1.4302
# Epoch 81/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9358 - loss: 0.1980 - val_accuracy: 0.6711 - val_loss: 1.4454
# Epoch 82/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9412 - loss: 0.1797 - val_accuracy: 0.6817 - val_loss: 1.3737
# Epoch 83/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9397 - loss: 0.1811 - val_accuracy: 0.6751 - val_loss: 1.4515
# Epoch 84/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9336 - loss: 0.2027 - val_accuracy: 0.6742 - val_loss: 1.4094
# Epoch 85/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9376 - loss: 0.1889 - val_accuracy: 0.6832 - val_loss: 1.3927
# Epoch 86/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9378 - loss: 0.1869 - val_accuracy: 0.6761 - val_loss: 1.3477
# Epoch 87/100
# 1563/1563 - 11s - 7ms/step - accuracy: 0.9367 - loss: 0.1897 - val_accuracy: 0.6868 - val_loss: 1.3628
# Epoch 88/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9404 - loss: 0.1825 - val_accuracy: 0.6929 - val_loss: 1.4241
# Epoch 89/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9386 - loss: 0.1854 - val_accuracy: 0.6827 - val_loss: 1.4564
# Epoch 90/100
# 1563/1563 - 9s - 6ms/step - accuracy: 0.9369 - loss: 0.1906 - val_accuracy: 0.6779 - val_loss: 1.4313
# Epoch 91/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9399 - loss: 0.1855 - val_accuracy: 0.6881 - val_loss: 1.4372
# Epoch 92/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9406 - loss: 0.1813 - val_accuracy: 0.6818 - val_loss: 1.3912
# Epoch 93/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9417 - loss: 0.1802 - val_accuracy: 0.6855 - val_loss: 1.3144
# Epoch 94/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9399 - loss: 0.1817 - val_accuracy: 0.6805 - val_loss: 1.5186
# Epoch 95/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9401 - loss: 0.1828 - val_accuracy: 0.6811 - val_loss: 1.4082
# Epoch 96/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9433 - loss: 0.1751 - val_accuracy: 0.6862 - val_loss: 1.3896
# Epoch 97/100
# 1563/1563 - 5s - 4ms/step - accuracy: 0.9391 - loss: 0.1824 - val_accuracy: 0.6805 - val_loss: 1.3547
# Epoch 98/100
# 1563/1563 - 6s - 4ms/step - accuracy: 0.9418 - loss: 0.1778 - val_accuracy: 0.6861 - val_loss: 1.3315
# Epoch 99/100
# 1563/1563 - 5s - 3ms/step - accuracy: 0.9443 - loss: 0.1729 - val_accuracy: 0.6855 - val_loss: 1.3978
# Epoch 100/100
# 1563/1563 - 10s - 7ms/step - accuracy: 0.9406 - loss: 0.1801 - val_accuracy: 0.6778 - val_loss: 1.5277
# Accuracy: 67.78%

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6839 - loss: 1.4903
# Test Accuracy: 67.78%

# %%
# Predict first 4 test images
predictions = model.predict(X_test[:4])

# Compare with actual labels
for i in range(4):
    print(f"Image {i+1}: Predicted Label: {predictions[i].argmax()}, Actual Label: {y_test[i].argmax()}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Image 1: Predicted Label: 3, Actual Label: 3
# Image 2: Predicted Label: 1, Actual Label: 8
# Image 3: Predicted Label: 8, Actual Label: 8
# Image 4: Predicted Label: 0, Actual Label: 0

# %%
# Visualize accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# Visualize loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
